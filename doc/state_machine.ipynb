# %%
# %%latex
# \begin{equation}
# State(\mathbf{S}) \times Event(\mathbf{E}) \rightarrow Actions(\mathbf{A}), State(\mathbf{S}')
# \end{equation}
# Out:
# \begin{equation}
# State(\mathbf{S}) \times Event(\mathbf{E}) \rightarrow Actions(\mathbf{A}), State(\mathbf{S}')
# \end{equation}
